# %%
import pandas as pd

file_path = '/home/toor/Desktop/home-abrotman-2024-05-29/evaluation-results/iteration-0/homeMay29-trainset95shuffle1/DLC_resnet50_homeMay29shuffle1_50000-snapshot-50000.h5'

df = pd.read_hdf(file_path)

print(df.head())  # to check the structure
# Out:
# scorer                                                      DLC_resnet50_homeMay29shuffle1_50000  \
# bodyparts                                                                              bodypart1
# coords                                                                                         x
# labeled-data behaviorLinear2024-05-24T18_42_16 img00256.png                           421.147067
#                                                img00943.png                           793.294816
#                                                img02998.png                          1299.318972
#                                                img03235.png                          1196.608811
#                                                img03816.png                           739.780804
#
# scorer                                                                   \
# bodyparts
# coords                                                                y
# ...

# %%
import h5py

file_path = '/home/toor/Desktop/home-abrotman-2024-05-29/evaluation-results/iteration-0/homeMay29-trainset95shuffle1/DLC_resnet50_homeMay29shuffle1_50000-snapshot-50000.h5'

with h5py.File(file_path, 'r') as f:
    # List all groups
    print("Keys:")
    print(list(f.keys()))
    
    # Explore a specific dataset
    for key in f.keys():
        print(f"{key} shape: {f[key].shape}")
# Out:
# Keys:
# ['df_with_missing']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 12
#      10 # Explore a specific dataset
#      11 for key in f.keys():
# ---> 12     print(f"{key} shape: {f[key].shape}")
#
# AttributeError: 'Group' object has no attribute 'shape'
